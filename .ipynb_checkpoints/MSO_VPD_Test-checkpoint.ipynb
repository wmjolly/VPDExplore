# %% [markdown]
# ## Vapor Pressure Deficit exploration
# ### Matt and Dana Work Session 07 Aug 2023

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import r2_score
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# ### FireFamilyPlus Dewpoint, Sat Vapor Pressure and VPD Calculations

# %%
# Calculate Dewpoint temperature from Temp and RH
def CalcDPT(tempF, RH):
	safeTemp = min(140.0, tempF)
	safeRH = max(5.0, RH)
	dp = -398.36 - 7428.6 / (-15.674 + math.log(safeRH / 100.0 * math.exp(-7482.6/(safeTemp + 398.36) + 15.675)))
	return dp

# Calculate the Vapor Pressure from Temperature(F)
def  CalcVP(tempF):
    tmpC =  (tempF - 32.0) / 1.8
    vp = 610.7 * math.exp((17.38 * tmpC)/(239 + tmpC))
    #print(tmpC)
    return vp

# Calculate the VPD from RH and Temperature(F)
def CalcVPD(RH, TempF):
    vp = CalcVP(TempF)
    vpd = vp - (RH / 100) * vp
    if(vpd < 0.0):
        vpd = 0.0
    return vpd

# Calculate the Actual Vapor Pressure from VPSat(Pa) and RH(%)
def CalcVPAct(VPSat,RH):
    return (RH / 100) * VPSat

# %% [markdown]
# ### First, read the FW21 (hourly) into a Pandas DataFrame

# %%
df = pd.read_csv("./Data/FW21//MSO.fw21.csv")

# %%
df.head()
# Out:
#            DateTime   Temperature(F)   RelativeHumidity(%)  \
# 0  20020101T000000Z             28.0                  84.0
# 1  20020101T010000Z             27.0                  86.0
# 2  20020101T020000Z             27.0                  87.0
# 3  20020101T030000Z             27.0                  86.0
# 4  20020101T040000Z             26.0                  87.0
#
#     Precipitation(in)   WindSpeed(mph)   WindAzimuth(degrees)  \
# 0                 0.0              2.0                  241.0
# 1                 0.0              3.0                  238.0
# 2                 0.0              3.0                  210.0
# 3                 0.0              3.0                  218.0
# 4                 0.0              3.0                  222.0
#
#     SolarRadiation(W/m2)   SnowFlag
# 0                    5.0        1.0
# 1                    0.0        1.0
# 2                    0.0        1.0
# 3                    0.0        1.0
# 4                    0.0        1.0

# %% [markdown]
# ### Let's fix some of the datatypes in the DataFrame

# %%
siteName = "Missoula"
df.rename(columns=lambda x: x.strip(), inplace=True)
df['DateTime']=pd.to_datetime(df['DateTime'].astype(str))
df.set_index(df.DateTime,inplace=True)
df.DateTime.dtype
# Out:
# datetime64[ns, UTC]

# %%
# Filter for any bad data
df = df[(df['Precipitation(in)']<5)]

# %% [markdown]
# ### Let's read in the daily data files too for longer time series analysis

# %%
df_daily = pd.read_csv("./Data/CSV/241513_daily.csv")
df_daily.rename(columns=lambda x: x.strip(), inplace=True)
df_daily['DateTime']=pd.to_datetime(df_daily['DATE'].astype(str) + " 13", format='%m/%d/%Y %H')

# %%
df_daily.head()
# Out:
#        DATE  MaxT  MinT  MxRH  MnRH  Rain  DPT    VPDA    VPDM  \
# 0  7/1/1971  79.0  45.0  60.0   2.0  0.00   44   907.0  3315.0
# 1  7/2/1971  78.0  52.0  96.0  24.0  0.00   44  1133.0  2488.0
# 2  7/3/1971  77.0  42.0  66.0  19.0  0.00   28  1182.0  2565.0
# 3  7/4/1971  72.0  43.0  99.0  30.0  0.03   40   738.0  1875.0
# 4  7/5/1971  83.0  49.0  99.0  22.0  0.05   38  1415.0  3005.0
#
#              DateTime
# 0 1971-07-01 13:00:00
# 1 1971-07-02 13:00:00
# 2 1971-07-03 13:00:00
# 3 1971-07-04 13:00:00
# 4 1971-07-05 13:00:00

# %%
df_daily['MaxT'].groupby(df_daily['DateTime'].dt.year).max('MaxT').plot()
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %% [markdown]
# ### Let's plot the Saturation Vapor Pressure curve

# %%
f,ax =plt.subplots()
vp = []
for t in range(0,110):
    vp.append(CalcVP(t))
plt.plot(vp)
plt.grid()
ax.set_xlabel('Temperature (F)')
ax.set_ylabel('Vapor Pressure (Pa)')
# Out:
# Text(0, 0.5, 'Vapor Pressure (Pa)')

# %% [markdown]
# ### Let's calculate the Saturation Vapor Pressure for our weather observations

# %%
VPSat = df.apply(lambda row: CalcVP(row['Temperature(F)']),axis=1)
df = df.copy()
df['VPSat(Pa)'] = VPSat

# %% [markdown]
# ### Let's calculate the Dewpoint Temperature from the weather data

# %%
DPT = df.apply(lambda row: CalcDPT(row['Temperature(F)'],row['RelativeHumidity(%)']),axis=1)
df['DewpointTemperature(F)'] = DPT

# %%
# Plot the dewpoint temperature times series
df['DewpointTemperature(F)'].plot()
plt.grid()

# %%
df['DewpointTemperature(F)'].plot.hist(bins=35)
plt.grid()

# %%
# Plot mean daily VPSat
df['VPSat(Pa)'].groupby(df['DateTime'].dt.dayofyear).mean(['VPSat(Pa)']).plot()
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %% [markdown]
# ### Now, Let's calculate the Actual Vapor Pressure (VPAct)

# %%
df.loc[:,'VPAct(Pa)'] = (df['RelativeHumidity(%)']/ 100) * df['VPSat(Pa)']

# %% [markdown]
# https://colorbrewer2.org/#type=diverging&scheme=RdYlBu&n=5

# %% [markdown]
# ### Let's plot the differences between VPAct and VPSat

# %%
f,ax = plt.subplots()
df['VPSat(Pa)'].groupby(df['DateTime'].dt.dayofyear).mean(['VPSat(Pa)']).plot(ax=ax,color='#d7191c',label='VPSat',legend=True)
df['VPAct(Pa)'].groupby(df['DateTime'].dt.dayofyear).mean(['VPAct(Pa)']).plot(ax=ax,color='#2c7bb6',label='VPAct',legend=True)
plt.grid()
ax.set_xlabel('Day of Year')
ax.set_ylabel('Vapor Pressure (Pa)')
# Out:
# Text(0, 0.5, 'Vapor Pressure (Pa)')

# %% [markdown]
# ## Let's calculate VPD from VPSat and VPAct

# %%
df.loc[:,'VPD(Pa)'] = df['VPSat(Pa)'] - df['VPAct(Pa)']

# %%
varname = 'VPD(Pa)'
f,ax = plt.subplots()
df[varname].groupby(df['DateTime'].dt.dayofyear).min(varname).plot(ax=ax,color='#2c7bb6',label="Min",legend=True)
df[varname].groupby(df['DateTime'].dt.dayofyear).mean(varname).plot(ax=ax,color='#fee090',label="Mean",legend=True)
df[varname].groupby(df['DateTime'].dt.dayofyear).max(varname).plot(ax=ax,color='#d7191c',label="Max",legend=True)
plt.grid()
ax.set_title(f"Missoula {varname} (2001-2023)")
ax.set_xlabel("Day of year")
ax.set_ylabel(varname)
# Out:
# Text(0, 0.5, 'VPD(Pa)')

# %% [markdown]
# ### Let's print some ranges to explore the data

# %%
### Now let's plot them together (Sat and Act)

# %%
print(df['WindSpeed(mph)'].min())
print(df['WindSpeed(mph)'].mean())
print(df['WindSpeed(mph)'].max())
# Out:
# 0.0
# 2.2433442594575883
# 26.0

# %%
# Example of a data summary over a fixed time period
df['Temperature(F)'].resample('2Y').mean()
# Out:
# DateTime
# 2002-12-31 00:00:00+00:00    44.337138
# 2004-12-31 00:00:00+00:00    48.140509
# 2006-12-31 00:00:00+00:00    45.706087
# 2008-12-31 00:00:00+00:00    45.224143
# 2010-12-31 00:00:00+00:00    44.339847
# 2012-12-31 00:00:00+00:00    45.350217
# 2014-12-31 00:00:00+00:00    45.459882
# 2016-12-31 00:00:00+00:00    46.892279
# 2018-12-31 00:00:00+00:00    45.287355
# 2020-12-31 00:00:00+00:00    44.291562
# 2022-12-31 00:00:00+00:00    45.362909
# 2024-12-31 00:00:00+00:00    46.219726
# Freq: 2A-DEC, Name: Temperature(F), dtype: float64

# %%
df['Temperature(F)'].resample('2M').mean().plot(color='#2c7bb6')
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %% [markdown]
# ### Let's plot annual summaries by percentiles

# %%
varname = 'Temperature(F)'
perc = 0.75
f,ax = plt.subplots()
df[varname].groupby(df['DateTime'].dt.year).quantile(perc).plot(ax=ax,color='#2c7bb6')
plt.grid()
ax.set_title(f"Annual {perc*100}th  percentile {varname} (2001-2023) (Missoula)")
ax.set_xlabel("Year")
ax.set_ylabel(varname)
# Out:
# Text(0, 0.5, 'Temperature(F)')

# %%
f,ax = plt.subplots()
plt.scatter(df['DewpointTemperature(F)'],df['VPD(Pa)'])
plt.grid()
ax.set_title("Compare Dewpoint Temperature to VPD")
# Out:
# Text(0.5, 1.0, 'Compare Dewpoint Temperature to VPD')

# %%
f,ax = plt.subplots()
df['RelativeHumidity(%)'].groupby(df['DateTime'].dt.dayofyear).mean('RelativeHumidity(%)').plot(ax=ax,label="Mean RH",legend=True,color='#2c7bb6')
df['VPD(Pa)'].groupby(df['DateTime'].dt.dayofyear).mean('VPD(Pa)').plot(ax=ax,secondary_y = True,label="Mean VPD",legend=True,color='#d7191c')
# Out:
# <AxesSubplot:>

# %%
VPDMeanDaily = df['VPD(Pa)'].groupby(df['DateTime'].dt.dayofyear).mean('VPD(Pa)')
RHMeanDaily = df['RelativeHumidity(%)'].groupby(df['DateTime'].dt.dayofyear).mean('RelativeHumidity(%)')

# %%
f,ax = plt.subplots()
plt.scatter(RHMeanDaily,VPDMeanDaily)
ax.set_xlabel("Mean Daily RH (%)")
ax.set_ylabel("Mean Daily VPD (Pa)")
# Out:
# Text(0, 0.5, 'Mean Daily VPD (Pa)')

# %%
df[df['VPD(Pa)'] > 7000]
# Out:
#                                            DateTime  Temperature(F)  \
# DateTime
# 2007-07-06 23:00:00+00:00 2007-07-06 23:00:00+00:00           107.0
#
#                            RelativeHumidity(%)  Precipitation(in)  \
# DateTime
# 2007-07-06 23:00:00+00:00                 12.0                0.0
#
#                            WindSpeed(mph)  WindAzimuth(degrees)  \
# DateTime
# 2007-07-06 23:00:00+00:00             4.0                  23.0
#
#                            SolarRadiation(W/m2)  SnowFlag    VPSat(Pa)  \
# DateTime
# 2007-07-06 23:00:00+00:00                 811.0       0.0  8060.832444
#
#                            DewpointTemperature(F)   VPAct(Pa)     VPD(Pa)
# DateTime
# 2007-07-06 23:00:00+00:00                40.53371  967.299893  7093.53255

# %%
AnnMaxT = df_daily['MaxT'].groupby(df_daily['DateTime'].dt.year).max('MaxT')

# %%
X = AnnMaxT.index.values#.reshape(-1, 1)  # values converts it into a numpy array
y = AnnMaxT.iloc[:].values#.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     12.47
# Date:                Wed, 09 Aug 2023   Prob (F-statistic):           0.000889
# Time:                        16:47:01   Log-Likelihood:                -128.08
# No. Observations:                  53   AIC:                             260.2
# Df Residuals:                      51   BIC:                             264.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -75.4653     49.574     -1.522      0.134    -174.989      24.058
# x1             0.0876      0.025      3.531      0.001       0.038       0.137
# ==============================================================================
# Omnibus:                        0.612   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.736   Jarque-Bera (JB):                0.734
# Skew:                           0.157   Prob(JB):                        0.693
# Kurtosis:                       2.517   Cond. No.                     2.61e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Fit with scikit-learn
X = AnnMaxT.index.values.reshape(-1, 1)  # values converts it into a numpy array
Y =  AnnMaxT.iloc[:].values#.reshape(-1, 1)   # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
f,ax = plt.subplots()
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.grid()
ax.set_xlabel("Year")
ax.set_ylabel("Annual Maximum Temperature (F)")
# Out:
# Text(0, 0.5, 'Annual Maximum Temperature (F)')

# %%
df['VPD(Pa)'].rolling(24).std().groupby(df['DateTime'].dt.dayofyear).mean().plot()
# Out:
# <AxesSubplot:xlabel='DateTime'>
